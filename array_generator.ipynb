# %%
from diode_array import diode_array
import numpy as np
directory = "" # change this as needed

# %%
demo_32x32_params= {
    "pad_dimensions": np.array([60, 60, 5]), # [width, length, padding for vertical pads]
    "pad_pitch": 100, # distance between pad centers
    "bar_width": 20, 
    "bar_pitch": 40, # distance between bar centers
    "num_bars": np.array([16, 16]), # [x, y]
    "circle_radius": 5,
    "bar_pad_spacing": np.array([120, 120]), # spacing between bar and pad
    "interleaved_pad_spacing": 15, # spacing between interleaved pads, only used for interleaved pad style
    "pad_route_dist": 20,
    "pad_style": "interleaved", # "double", "interleaved", "single", or "single_line"
    "route_thetas": [np.pi/4, np.pi/4], # angle of route from pad to bar in radians
    "text_size": 40,
    "invert_be": True
}

# %%
demo_32x32_array = diode_array(demo_32x32_params)
demo_32x32_array.draw()

# %%
params_2kb_small = {
    "pad_dimensions": np.array([100, 100, 5]), # [width, length, padding for vertical pads]
    "pad_pitch": 120, # distance between pad centers
    "bar_width": 10, 
    "bar_pitch": 20, # distance between bar centers
    "num_bars": np.array([128, 128]), # [x, y]
    "circle_radius": 2.5,
    "bar_pad_spacing": np.array([2600, 2600]), # spacing between bar and pad
    "interleaved_pad_spacing": 15, # spacing between interleaved pads, only used for interleaved pad style
    "pad_route_dist": 20,
    "pad_style": "single", # "double", "interleaved", or "single"
    "route_thetas": [np.pi/4, np.pi/4], # angle of route from pad to bar in radians
    "text_size": 40,
    "invert_be": True
}

# %%
array_2kb_small = diode_array(params_2kb_small)
array_2kb_small.draw()
array_2kb_small.save(directory=directory, filename="2kb_small_array")
